# %%
#Matrices
import numpy as np

#Matemáticas
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats

import statsmodels.graphics.tsaplots as sgt 
import statsmodels.tsa.stattools as sts 
from statsmodels.tsa.seasonal import seasonal_decompose
import seaborn as sns
sns.set()

from pandas import ExcelWriter
from pandas import ExcelFile
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Nueva sección

# %%
#Funcion para cargar datos
def cargando_datos(Col_uso, nombre_archivo,separacion):
     ubicacion='/content/drive/MyDrive/UCentral/ProgramacionAnalitica/ProyectoAnalitica/'+nombre_archivo
     #df_datos=pd.read_csv(ubicacion, sep = separacion,usecols=Col_uso)
     df_datos = pd.read_excel(ubicacion, sheet_name='Sheet1')
     return df_datos

def convertir_fecha_key(df_convertir):
    df_convertir.Fecha = pd.to_datetime(df_convertir.Fecha)
    df_convertir.set_index("Fecha",inplace=True)
    return df_convertir

# %%
Col_uso=['C.O.','Desc. C.O.','Fecha','Item','Referencia','Desc. item','Detalle ext. 1','Desc. detalle ext. 1','Tipo docto.','Nro documento','Estado movto.','Bodega','U.M.','Cant. pedida','Valor subtotal local','Cliente factura','Razón social cliente factura','Código vendedor','Nombre vendedor','Condición de pago','Desc. condición de pago','Desc. cond. pago fact','Desc. tipo inventario','ORIGEN','DEPARTAMENTO','CATEGORIA','SUBCATEGORIA']

"""df_grandesSup=cargando_datos(Col_uso,'Grandes_Superficies.csv',',')
Col_uso=['Sector','Fecha','Valor']
df_pib=cargando_datos(Col_uso,'pib.csv',';')
Col_uso=['Trimestre','Pom Inf Trim']
df_inflacion=cargando_datos(Col_uso,'inflacion.csv',';')"""

df_pedidos=cargando_datos(Col_uso,'PEDIDOS_POR_ITEM.xls',',')
#/content/drive/MyDrive/UCentral/ProgramacionAnalitica/ProyectoAnalitica/PEDIDOS POR ITEM.csv
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-37-659394af5e31> in <module>()
#       7 df_inflacion=cargando_datos(Col_uso,'inflacion.csv',';')"""
#       8
# ----> 9 df_pedidos=cargando_datos(Col_uso,'PEDIDOS_POR_ITEM.xls',',')
#      10 #/content/drive/MyDrive/UCentral/ProgramacionAnalitica/ProyectoAnalitica/PEDIDOS POR ITEM.csv
#
# <ipython-input-36-c6d8cd4eac49> in cargando_datos(Col_uso, nombre_archivo, separacion)
#       3      ubicacion='/content/drive/MyDrive/UCentral/ProgramacionAnalitica/ProyectoAnalitica/'+nombre_archivo
#       4      #df_datos=pd.read_csv(ubicacion, sep = separacion,usecols=Col_uso)
# ----> 5      df_datos = pd.read_excel(ubicacion, sheet_name='Sheet1')
#       6      return df_datos
#       7
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
df_pedidos
# Out:
#                         Fecha   Estado       Total
# 0      08/18/2016 12:00:00 AM  Emitida  11927277.0
# 1      08/19/2016 12:00:00 AM  Emitida    490000.0
# 2      11/02/2021 12:00:00 AM  Emitida   1068700.0
# 3      12/18/2014 12:00:00 AM  Emitida  16038603.0
# 4      08/19/2016 12:00:00 AM  Emitida   9644416.0
# ...                       ...      ...         ...
# 20856  08/12/2016 12:00:00 AM  Emitida   3419404.0
# 20857  08/16/2016 12:00:00 AM  Emitida   4325090.0
# 20858  08/16/2016 12:00:00 AM  Emitida    386900.0
# 20859  08/16/2016 12:00:00 AM  Emitida   1065800.0
# 20860  08/16/2016 12:00:00 AM  Emitida   2276798.0
#
# [20861 rows x 3 columns]

# %%
df_grandesSup.describe()
# Out:
#               Total
# count  2.086100e+04
# mean   1.490118e+07
# std    2.854924e+07
# min    0.000000e+00
# 25%    2.118915e+06
# 50%    5.921443e+06
# 75%    1.775373e+07
# max    2.008500e+09

# %%
df_grandesSup['Ventas']=df_grandesSup['Total']/100000

# %%
df_grandesSup
# Out:
#                         Fecha   Estado       Total     Ventas
# 0      08/18/2016 12:00:00 AM  Emitida  11927277.0  119.27277
# 1      08/19/2016 12:00:00 AM  Emitida    490000.0    4.90000
# 2      11/02/2021 12:00:00 AM  Emitida   1068700.0   10.68700
# 3      12/18/2014 12:00:00 AM  Emitida  16038603.0  160.38603
# 4      08/19/2016 12:00:00 AM  Emitida   9644416.0   96.44416
# ...                       ...      ...         ...        ...
# 20856  08/12/2016 12:00:00 AM  Emitida   3419404.0   34.19404
# 20857  08/16/2016 12:00:00 AM  Emitida   4325090.0   43.25090
# 20858  08/16/2016 12:00:00 AM  Emitida    386900.0    3.86900
# 20859  08/16/2016 12:00:00 AM  Emitida   1065800.0   10.65800
# 20860  08/16/2016 12:00:00 AM  Emitida   2276798.0   22.76798
#
# [20861 rows x 4 columns]

# %% [markdown]
# #Quiero ver que categorias tiene estado, primero las convierto

# %%
df_grandesSup["Estado"]=df_grandesSup["Estado"].astype("category")
df_grandesSup["Estado"]
# Out:
# 0        Emitida
# 1        Emitida
# 2        Emitida
# 3        Emitida
# 4        Emitida
#           ...
# 20856    Emitida
# 20857    Emitida
# 20858    Emitida
# 20859    Emitida
# 20860    Emitida
# Name: Estado, Length: 20861, dtype: category
# Categories (2, object): ['Cerrada', 'Emitida']

# %%
df_grandesSup["Estado"].hist();

# %%
df_grsp_emitida=df_grandesSup=df_grandesSup.loc[df_grandesSup.loc[:, 'Estado'] == 'Emitida']
df_grsp_emitida
# Out:
#                         Fecha   Estado       Total     Ventas
# 0      08/18/2016 12:00:00 AM  Emitida  11927277.0  119.27277
# 1      08/19/2016 12:00:00 AM  Emitida    490000.0    4.90000
# 2      11/02/2021 12:00:00 AM  Emitida   1068700.0   10.68700
# 3      12/18/2014 12:00:00 AM  Emitida  16038603.0  160.38603
# 4      08/19/2016 12:00:00 AM  Emitida   9644416.0   96.44416
# ...                       ...      ...         ...        ...
# 20856  08/12/2016 12:00:00 AM  Emitida   3419404.0   34.19404
# 20857  08/16/2016 12:00:00 AM  Emitida   4325090.0   43.25090
# 20858  08/16/2016 12:00:00 AM  Emitida    386900.0    3.86900
# 20859  08/16/2016 12:00:00 AM  Emitida   1065800.0   10.65800
# 20860  08/16/2016 12:00:00 AM  Emitida   2276798.0   22.76798
#
# [16275 rows x 4 columns]

# %%
df_grandesSup["Estado"].hist();

# %%
convertir_fecha_key(df_grandesSup)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#              Estado       Total     Ventas
# Fecha
# 2016-08-18  Emitida  11927277.0  119.27277
# 2016-08-19  Emitida    490000.0    4.90000
# 2021-11-02  Emitida   1068700.0   10.68700
# 2014-12-18  Emitida  16038603.0  160.38603
# 2016-08-19  Emitida   9644416.0   96.44416
# ...             ...         ...        ...
# 2016-08-12  Emitida   3419404.0   34.19404
# 2016-08-16  Emitida   4325090.0   43.25090
# 2016-08-16  Emitida    386900.0    3.86900
# 2016-08-16  Emitida   1065800.0   10.65800
# 2016-08-16  Emitida   2276798.0   22.76798
#
# [16275 rows x 3 columns]

# %%
df_grandesSup
# Out:
#              Estado       Total     Ventas
# Fecha
# 2016-08-18  Emitida  11927277.0  119.27277
# 2016-08-19  Emitida    490000.0    4.90000
# 2021-11-02  Emitida   1068700.0   10.68700
# 2014-12-18  Emitida  16038603.0  160.38603
# 2016-08-19  Emitida   9644416.0   96.44416
# ...             ...         ...        ...
# 2016-08-12  Emitida   3419404.0   34.19404
# 2016-08-16  Emitida   4325090.0   43.25090
# 2016-08-16  Emitida    386900.0    3.86900
# 2016-08-16  Emitida   1065800.0   10.65800
# 2016-08-16  Emitida   2276798.0   22.76798
#
# [16275 rows x 3 columns]

# %%
df_pib
# Out:
#                                                 Sector       Fecha    Valor
# 0    Agricultura, ganadería, caza, silvicultura y p...  31/10/2014   10.821
# 1    Agricultura, ganadería, caza, silvicultura y p...  31/01/2015   11.487
# 2    Agricultura, ganadería, caza, silvicultura y p...  30/04/2015   11.504
# 3    Agricultura, ganadería, caza, silvicultura y p...  31/07/2015   12.236
# 4    Agricultura, ganadería, caza, silvicultura y p...  31/10/2015   12.896
# ..                                                 ...         ...      ...
# 359                             Producto interno bruto  31/07/2020  246.729
# 360                             Producto interno bruto  31/10/2020  267.459
# 361                             Producto interno bruto  31/01/2021  278.254
# 362                             Producto interno bruto  30/04/2021  281.225
# 363                             Producto interno bruto  31/07/2021  305.156
#
# [364 rows x 3 columns]

# %%
#df_pib["Sector"]=df_pib["Sector"].astype("category")
#df_pib["Sector"]

# %%
df_pib.plot.scatter(x='Valor',y='Sector');
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
df_pib.plot.scatter(x='Sector',y='Valor');
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
#Voy a renombrar las categorias.. puedo crear un diccionario dandole una codificacion a cada una

#Realizamos un diccionario con la codificación

codificamos={
             k:i
             for i,k in enumerate(df_pib['Sector'].unique(),0)           
}

codificamos

df_pib['item_sector']=df_pib['Sector'].map(codificamos)
df_pib
# Out:
#                                                 Sector       Fecha    Valor  \
# 0    Agricultura, ganadería, caza, silvicultura y p...  31/10/2014   10.821
# 1    Agricultura, ganadería, caza, silvicultura y p...  31/01/2015   11.487
# 2    Agricultura, ganadería, caza, silvicultura y p...  30/04/2015   11.504
# 3    Agricultura, ganadería, caza, silvicultura y p...  31/07/2015   12.236
# 4    Agricultura, ganadería, caza, silvicultura y p...  31/10/2015   12.896
# ..                                                 ...         ...      ...
# 359                             Producto interno bruto  31/07/2020  246.729
# 360                             Producto interno bruto  31/10/2020  267.459
# 361                             Producto interno bruto  31/01/2021  278.254
# 362                             Producto interno bruto  30/04/2021  281.225
# 363                             Producto interno bruto  31/07/2021  305.156
#
#      item_sector
# 0              0
# 1              0
# ...

# %%
df_pib.plot.scatter(x='item_sector',y='Valor');
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
df_pib.plot.scatter(x='item_sector',y='Sector');
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
df_pib.plot.scatter(x='item_sector',y='Sector');
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
#Separar el valor el PIB de los demas datos 
#Sumatoria_pib=df_pib[df_pib.item_sector < 12]
df_pib[df_pib.item_sector < 12].plot.scatter(x='item_sector',y='Sector');
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
df_pib.groupby("item_sector").size()
# Out:
# item_sector
# 0     28
# 1     28
# 2     28
# 3     28
# 4     28
# 5     28
# 6     28
# 7     28
# 8     28
# 9     28
# 10    28
# 11    28
# 12    28
# dtype: int64

# %%
Sector_Publica_defensa=(df_pib[df_pib.item_sector==10])
Sector_Educacion=(df_pib[df_pib.item_sector==9])
Sector_Comercio=(df_pib[df_pib.item_sector==5])
Sector_Financiera=(df_pib[df_pib.item_sector==7])

# %%
Sector_Publica_defensa['Valor'].plot(figsize = (20,5), color = "red")
plt.title("PIB", size = 24)
plt.show()

# %%
df_pib[df_pib.item_sector==9]['Valor'].plot(figsize = (20,5), color = "red")
plt.title("Educación", size = 24)
plt.show()

# %%
df_pib
# Out:
#                                                 Sector       Fecha    Valor  \
# 0    Agricultura, ganadería, caza, silvicultura y p...  31/10/2014   10.821
# 1    Agricultura, ganadería, caza, silvicultura y p...  31/01/2015   11.487
# 2    Agricultura, ganadería, caza, silvicultura y p...  30/04/2015   11.504
# 3    Agricultura, ganadería, caza, silvicultura y p...  31/07/2015   12.236
# 4    Agricultura, ganadería, caza, silvicultura y p...  31/10/2015   12.896
# ..                                                 ...         ...      ...
# 359                             Producto interno bruto  31/07/2020  246.729
# 360                             Producto interno bruto  31/10/2020  267.459
# 361                             Producto interno bruto  31/01/2021  278.254
# 362                             Producto interno bruto  30/04/2021  281.225
# 363                             Producto interno bruto  31/07/2021  305.156
#
#      item_sector
# 0              0
# 1              0
# ...

# %%
convertir_fecha_key(df_pib)
# Out:
#                                                        Sector    Valor  \
# Fecha
# 2014-10-31  Agricultura, ganadería, caza, silvicultura y p...   10.821
# 2015-01-31  Agricultura, ganadería, caza, silvicultura y p...   11.487
# 2015-04-30  Agricultura, ganadería, caza, silvicultura y p...   11.504
# 2015-07-31  Agricultura, ganadería, caza, silvicultura y p...   12.236
# 2015-10-31  Agricultura, ganadería, caza, silvicultura y p...   12.896
# ...                                                       ...      ...
# 2020-07-31                             Producto interno bruto  246.729
# 2020-10-31                             Producto interno bruto  267.459
# 2021-01-31                             Producto interno bruto  278.254
# 2021-04-30                             Producto interno bruto  281.225
# 2021-07-31                             Producto interno bruto  305.156
#
#             item_sector
# Fecha
# 2014-10-31            0
# 2015-01-31            0
# ...

# %%
df_pib[df_pib.item_sector==9]['Valor'].plot(figsize = (20,5), color = "red")
plt.title("Educación", size = 24)
plt.show()

# %%
df_grandesSup['Ventas'].plot(figsize = (20,5), color = "red")
plt.title("Ventas", size = 24)
plt.show()

# %%
#vamos a trabajar con las quesolo se han emitido
df_grsp_emitida
# Out:
#              Estado       Total     Ventas
# Fecha
# 2016-08-18  Emitida  11927277.0  119.27277
# 2016-08-19  Emitida    490000.0    4.90000
# 2021-11-02  Emitida   1068700.0   10.68700
# 2014-12-18  Emitida  16038603.0  160.38603
# 2016-08-19  Emitida   9644416.0   96.44416
# ...             ...         ...        ...
# 2016-08-12  Emitida   3419404.0   34.19404
# 2016-08-16  Emitida   4325090.0   43.25090
# 2016-08-16  Emitida    386900.0    3.86900
# 2016-08-16  Emitida   1065800.0   10.65800
# 2016-08-16  Emitida   2276798.0   22.76798
#
# [16275 rows x 3 columns]

# %%
#vamos trabajar con el comportamiento de la variable en funcion de la fecha
df_grsp_emitida['Ventas'].plot(figsize = (20,5), color = "red")
plt.title("Ventas", size = 24)
plt.show()

# %%
df_grsp_emitida_fecha=df_grsp_emitida.resample('Q').mean()
df_grsp_emitida_fecha
# Out:
#                    Total      Ventas
# Fecha
# 2014-12-31  1.269219e+07  126.921936
# 2015-03-31  8.374931e+06   83.749311
# 2015-06-30  5.795021e+06   57.950208
# 2015-09-30  1.091263e+07  109.126295
# 2015-12-31  1.226043e+07  122.604304
# 2016-03-31  1.659721e+07  165.972135
# 2016-06-30  1.102326e+07  110.232609
# 2016-09-30  9.030410e+06   90.304101
# 2016-12-31  1.206889e+07  120.688915
# 2017-03-31  1.195569e+07  119.556914
# 2017-06-30  1.495523e+07  149.552255
# 2017-09-30  1.048211e+07  104.821093
# 2017-12-31  1.484215e+07  148.421466
# 2018-03-31  1.499111e+07  149.911075
# 2018-06-30  1.282400e+07  128.239951
# 2018-09-30  1.067593e+07  106.759294
# 2018-12-31  1.381513e+07  138.151309
# 2019-03-31  1.585614e+07  158.561416
# 2019-06-30  1.465114e+07  146.511371
# 2019-09-30  1.341448e+07  134.144803
# 2019-12-31  1.484550e+07  148.455014
# 2020-03-31  2.359594e+07  235.959450
# 2020-06-30  1.898573e+07  189.857335
# 2020-09-30  1.278124e+07  127.812363
# ...

# %%
#vamos trabajar con el comportamiento de la variable en funcion de la fecha
df_grsp_emitida_fecha['Ventas'].plot(figsize = (20,5), color = "red")
plt.title("Ventas", size = 24)
plt.show()

# %%
df_pib[df_pib.item_sector==9]['Valor'].plot(figsize = (20,5), color = "red")
plt.title("Educación", size = 24)
plt.show()

# %%
df_grsp_emitida_fecha.isnull()
# Out:
#             Total  Ventas
# Fecha
# 2014-12-31  False   False
# 2015-03-31  False   False
# 2015-06-30  False   False
# 2015-09-30  False   False
# 2015-12-31  False   False
# 2016-03-31  False   False
# 2016-06-30  False   False
# 2016-09-30  False   False
# 2016-12-31  False   False
# 2017-03-31  False   False
# 2017-06-30  False   False
# 2017-09-30  False   False
# 2017-12-31  False   False
# 2018-03-31  False   False
# 2018-06-30  False   False
# 2018-09-30  False   False
# 2018-12-31  False   False
# 2019-03-31  False   False
# 2019-06-30  False   False
# 2019-09-30  False   False
# 2019-12-31  False   False
# 2020-03-31  False   False
# 2020-06-30  False   False
# 2020-09-30  False   False
# 2020-12-31  False   False
# 2021-03-31  False   False
# 2021-06-30  False   False
# 2021-09-30  False   False
# 2021-12-31  False   False
# 2022-03-31  False   False

# %%
df_grsp_emitida_fecha.isnull().sum()
# Out:
# Total     0
# Ventas    0
# dtype: int64

# %%
#Vamos a revisar los datos de PIB
df_pib[df_pib.item_sector < 12].plot.scatter(x='item_sector',y='Sector');
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
scipy.stats.probplot(df_pib.item_sector=="12", plot =  plt)
plt.title("QQ Plot", size = 24)
plt.show()

#Grafico quantile-quantile
#nos ayuda a decifrar como se distribuyen los datos y saber si los datos se adapta a una distribucion normal, tipo de grafico plt
#parte de abajo representa los cuantiles teoricos, la linea roja representa la diferencia entre medias y como se deberian comportar su tienden a una distribución normal

# %%
#Importando
#df_comp="Index2018.csv"
#df_comp.describe()
#df_comp.head()
#df_comp.date.describe()
#df_comp.date = pd.to_datetime(df_comp.date, dayfirst = True)
#df_comp.head()
#df_comp.date.describe()
#df_comp.set_index("date", inplace=True)
#df_comp.head()
#df_comp.date.describe()
#df_comp=df_comp.asfreq('d')
#df_comp.head()
#df_comp=df_comp.asfreq('b')
#df_comp.head()
#df_comp.isna()
#df_comp.isna().sum()
#df_comp
#df_comp.spx=df_comp.spx.fillna(method='ffill')
#df_comp.isna().sum()
#df_comp.ftse=df_comp.ftse.fillna(method='bfill')
#df_comp.dax=df_comp.dax.fillna(value = df_comp.dax.mean())
#df_comp.nikkei=df_comp.dax.fillna(method='bfill')
#df_comp.isna().sum()
#df_comp['market_value']=df_comp.spx
#df_comp.describe()
#del df_comp['spx']
#df_comp.describe()
#del df_comp['dax']
#del df_comp['ftse']
#del df_comp['nikkei']
#df_comp.describe()
#size = int(len(df_comp)*0.8)
#df = df_comp.iloc[:size]
#df_test = df_comp.iloc[size:]
#df.tail()
#df_test.head()

# %%
#Cargando y transformando datos

raw_csv_data = pd.read_csv("/content/drive/MyDrive/Programación para analítica/Index2018.csv") 
df_comp=raw_csv_data.copy()
df_comp.date = pd.to_datetime(df_comp.date, dayfirst = True)
df_comp.set_index("date", inplace=True)
df_comp=df_comp.asfreq('b')
df_comp=df_comp.fillna(method='ffill')

# %%
df_comp['market_value']=df_comp.spx

del df_comp['spx']
del df_comp['dax']
del df_comp['ftse']
del df_comp['nikkei']
size = int(len(df_comp)*0.8)
df, df_test = df_comp.iloc[:size], df_comp.iloc[size:]

# %%
#White Noise
wn = np.random.normal(loc = df.market_value.mean(), scale = df.market_value.std(), size = len(df))
df['wn'] = wn
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.describe()
# Out:
#        market_value           wn
# count   5021.000000  5021.000000
# mean    1091.651926  1094.193236
# std      292.559287   293.042746
# min      438.920000   -71.672636
# 25%      914.620000   900.347673
# 50%     1144.650000  1097.323382
# 75%     1316.280729  1286.297819
# max     1570.252238  2176.247213

# %%
df.wn.plot(figsize = (20,5))
plt.title("White Noise Time-Series", size= 24)
plt.show()

# %%
df.market_value.plot(figsize=(20,5))
plt.title("S&P Prices", size = 24)
plt.ylim(0,2300)
plt.show()

# %%
rw = pd.read_csv("/content/drive/MyDrive/Programación para analítica/RandWalk.csv")

# %%
rw.head()
# Out:
#          date        price
# 0  07/01/1994  1122.139662
# 1  08/01/1994  1135.238562
# 2  09/01/1994  1109.897831
# 3  10/01/1994  1080.347860
# 4  11/01/1994  1082.095245

# %%
rw.date = pd.to_datetime(rw.date, dayfirst = True)

# %%
rw.set_index("date", inplace = True)

# %%
rw.head()
# Out:
#                   price
# date
# 1994-01-07  1122.139662
# 1994-01-08  1135.238562
# 1994-01-09  1109.897831
# 1994-01-10  1080.347860
# 1994-01-11  1082.095245

# %%
rw = rw.asfreq('b')

# %%
rw.describe()
# Out:
#              price
# count  5021.000000
# mean   1269.944293
# std     444.216793
# min     585.483034
# 25%     931.550429
# 50%    1156.363045
# 75%    1488.362029
# max    2715.508720

# %%
df['rw'] = rw.price
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.rw.plot(figsize = (20,5))
plt.title("Random Walk", size = 24)
plt.show()

# %%
df.rw.plot(figsize = (20,5))
df.market_value.plot()
plt.title("Random Walk vs S&P", size = 24)
plt.legend() 
plt.show()

# %%
#Estacionariedad
# significancia es menor pvalor rechazamos la h nula= no es estacionaria
# si estadistico es menor que eel nivel de significancia rechazamos la hipotesis nula= no estacionaria
#p-valor

sts.adfuller(df.market_value)
# Out:
# (-1.736984745235244,
#  0.41216456967706194,
#  18,
#  5002,
#  {'1%': -3.431658008603046,
#   '10%': -2.567077669247375,
#   '5%': -2.862117998412982},
#  39904.880607487445)

# %%
sts.adfuller(df.wn)
# Out:
# (-34.17333471166514,
#  0.0,
#  3,
#  5017,
#  {'1%': -3.431654095870046,
#   '10%': -2.5670767490325597,
#   '5%': -2.8621162697870046},
#  70814.2144858134)

# %%
sts.adfuller(df.rw)
# Out:
# (-1.3286073927689706,
#  0.615984918161739,
#  24,
#  4996,
#  {'1%': -3.4316595802782865,
#   '10%': -2.567078038881065,
#   '5%': -2.8621186927706463},
#  46299.333497595144)

# %%
#Estacionalidad
s_dec_additive = seasonal_decompose(df.market_value, model = "additive")
s_dec_additive.plot()
plt.show()

# %%
s_dec_multiplicative = seasonal_decompose(df.market_value, model = "multiplicative")
s_dec_multiplicative.plot()
plt.show()

# %%
#ACF
sgt.plot_acf(df.market_value, lags = 40, zero = False)
plt.title("ACF S&P", size = 24)
plt.show()

# %%
sgt.plot_acf(df.wn, lags = 40, zero = False)
plt.title("ACF WN", size = 24)
plt.show()

# %%
sgt.plot_acf(df.rw, lags = 40, zero = False)
plt.title("ACF RW", size = 24)
plt.show()

# %%
#PACF
sgt.plot_pacf(df.market_value, lags = 40, zero = False, method = ('ols'))
plt.title("PACF S&P", size = 24)
plt.show()

# %%
sgt.plot_pacf(df.wn, lags = 40, zero = False, method = ('ols'))
plt.title("PACF WN", size = 24)
plt.show()

# %%
sgt.plot_pacf(df.rw, lags = 40, zero = False, method = ('ols'))
plt.title("PACF RW", size = 24)
plt.show()
