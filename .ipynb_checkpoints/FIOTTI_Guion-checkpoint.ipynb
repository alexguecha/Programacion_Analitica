# %% [markdown]
# # Muebles Fiotti
#
# Es una industria nacional colombiana, con más de 32 años de experiencia en la fabricación, importación y comercialización de muebles para el hogar. A la fecha cuenta con un centro de distribución que surte alrededor de 10 tiendas a nivel nacional, en la cual se exhiben el catálogo de productos de sala, comedor, dormitorio y demás productos para la decoración del hogar.
#
# Así las cosas y con el propósito de llevar a cabo un entendimiento y correlación en cuanto al número de pedidos y el volumen de las ventas, la compañía ha facilitado una base de datos de las ventas realizadas entre octubre de  2021 a marzo del 2022, con la cual se busca aplicar  e implementar las técnicas y herramientas de analíticas de datos y series de tiempo disponibles en las librerías de Python como Pandas y Numpy entre otras.
#
# ## Objetivo general:
#
# Analizar el desempeño en cada una de la tiendas físicas Muebles Fiotti en relación con el número de pedidos y las ventas realizadas del catálogo de productos clasificados por departamentos categoría y subcategorías
#
# ## Objetivos específicos
#
# * Calcular a partir de la información suministrada por la compañía, una estimación de las ventas para los próximos tres meses,  para cada una de las tiendas físicas ubicadas en  la ciudad de Bogotá.
# * Descubrir patrones y tendencias que puedan existir entre las variables cualitativas que hacen parte de la base de datos como son: Tienda, día de la semana, departamento y categoría
# * Determinar el ranking o la posición de cada uno de los asesores de ventas de la compañía en función del total de ventas realizadas de forma diaria, semanal y mensual.
# * Aplicar la técnicas y funciones de las librerías de Python como Pandas, Numpy entre otras para la limpieza de los datos
# * Realizar análisis exploratorio de datos utilizando métodos estadísticos de las librerías matplotlib y scipy
#
# ## Variables Cualitativas a Analizar:
#
# * Departamento
# * Categoría
# * Subcategoría
# * Nombre Vendedor
# * Nombre Tienda
# * Estado (Comprometido, Aprobado, Cumplido)
#
# ## Variables Cuantitativas:
#
# * ValorTotal
# * ValorUnitario
# * Cantidad

# %%
import numpy as np

#Matemáticas
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats

import statsmodels.graphics.tsaplots as sgt 
import statsmodels.tsa.stattools as sts 
from statsmodels.tsa.seasonal import seasonal_decompose
import seaborn as sns
sns.set()

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
df= pd.read_excel("PEDIDOS_POR_ITEM.xls", sheet_name='Sheet1')

# %%
df.head()
# Out:
#    C.O.            Desc. C.O.      Fecha  Item  \
# 0   903     PAGINA WEB FIOTTI 2021-10-01   705
# 1   100  PUNTO DE VENTA AV 68 2021-10-01  1529
# 2   902      VENTAS DIGITALES 2021-10-01  1890
# 3   100  PUNTO DE VENTA AV 68 2021-10-01  4237
# 4   100  PUNTO DE VENTA AV 68 2021-10-01  1927
#
#                                           Referencia  \
# 0  AX0432                                        ...
# 1  XA0605                                        ...
# 2  XC0231                                        ...
# 3  D05307                                        ...
# 4  XC0022                                        ...
#
#                                  Desc. item        Detalle ext. 1  \
# 0  INDV SHAPE GOLD                                            NaN
# 1   ESPEJO DECORATIVO EDLIN REDONDO GRIS/NG                   NaN
# 2  TAPETE LAZARO GRIS/NEGRO/VER 140X200 435                   NaN
# 3                     SALA MODULAR CESAR 3C  00031
# 4   SALA L RECLINO MEAGAN CON BAUL NEGRO 3C                   NaN
#
#   Desc. detalle ext. 1 Tipo docto. Nro documento  ...          CATEGORIA  \
# 0                  NaN         PV    PV-00000014  ...    DEM - DECO MESA
# 1                  NaN         PV    PV-00000229  ...   DEC - DECORACIÓN
# 2                  NaN         PV    PV-00000177  ...      TAP - TAPETES
# 3            F-168 AGO         PV    PV-00000233  ...        SOF - SOFAS
# 4                  NaN         PV    PV-00000234  ...  REC - RECLINABLES
#
#                 SUBCATEGORIA Divisor márgen promedio  Divisor márgen estándar  \
# 0        INDV - INDIVIDUALES                   22521                    22521
# 1             ESPE - ESPEJOS                  607441                   607441
# 2  TAP3 - TAPETES 140X200 CM                  206900                   206900
# 3     MODU - SOFAS MODULARES                 2679748                  2679748
# 4    RCLL - RECLINABLES EN L                 2834370                  2834370
#
#    f_rowid_movto numero f_rowid_pv_docto f_rowid f_utilidad_promedio_f  \
# 0         589338     14           365336  365336               14113.0
# 1         589349    229           365342  365342              401917.6
# 2         589372    177           365356  365356              116257.0
# 3         589389    233           365362  365362             1148205.0
# 4         589390    234           365363  365363             1726947.0
#
#   id_clase_docto
# 0            502
# 1            503
# 2            502
# 3            503
# 4            503
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Limpieza de Datos
#
# Se excluyen alguana variables del dataset con la función **drop** de Panda, como se detalla a continuaicón:
# * Divisor márgen promedio
# * Divisor márgen estándar
# * f_rowid_movto
# * numero
# * f_rowid_pv_docto
# * f_rowid
# * f_utilidad_promedio_f
# * id_clase_docto
# * Detalle ext. 1
# * Desc. detalle ext. 1
# * U.M.
# * Condición de pago
# * Desc. condición de pago
# * Desc. cond. pago fact

# %%
df1=df.copy()

# %%
df2=df1.drop(['Divisor márgen promedio', 'Divisor márgen estándar', 'f_rowid_movto', 'numero', 'f_rowid_pv_docto', 'f_rowid','f_utilidad_promedio_f','id_clase_docto','Detalle ext. 1', 'Desc. detalle ext. 1','U.M.','Condición de pago', 'Desc. condición de pago', 'Desc. cond. pago fact'], axis=1)

# %%
df2.columns
# Out:
# Index(['C.O.', 'Desc. C.O.', 'Fecha', 'Item', 'Referencia', 'Desc. item',
#        'Tipo docto.', 'Nro documento', 'Estado movto.', 'Bodega',
#        'Cant. pedida', 'Valor subtotal local', 'Cliente factura',
#        'Razón social cliente factura', 'Código vendedor', 'Nombre vendedor',
#        'Desc. tipo inventario', 'ORIGEN', 'DEPARTAMENTO', 'CATEGORIA',
#        'SUBCATEGORIA'],
#       dtype='object')

# %%
df2.dtypes
# Out:
# C.O.                                     int64
# Desc. C.O.                              object
# Fecha                           datetime64[ns]
# Item                                     int64
# Referencia                              object
# Desc. item                              object
# Tipo docto.                             object
# Nro documento                           object
# Estado movto.                           object
# Bodega                                   int64
# Cant. pedida                             int64
# Valor subtotal local                     int64
# Cliente factura                         object
# Razón social cliente factura            object
# Código vendedor                         object
# Nombre vendedor                         object
# Desc. tipo inventario                   object
# ORIGEN                                  object
# DEPARTAMENTO                            object
# CATEGORIA                               object
# SUBCATEGORIA                            object
# dtype: object

# %% [markdown]
# ## Se establece la variabel ***Fecha*** como índice:

# %%
df2.set_index('Fecha', inplace = True)

# %%
df2.head()
# Out:
#             C.O.            Desc. C.O.  Item  \
# Fecha
# 2021-10-01   903     PAGINA WEB FIOTTI   705
# 2021-10-01   100  PUNTO DE VENTA AV 68  1529
# 2021-10-01   902      VENTAS DIGITALES  1890
# 2021-10-01   100  PUNTO DE VENTA AV 68  4237
# 2021-10-01   100  PUNTO DE VENTA AV 68  1927
#
#                                                    Referencia  \
# Fecha
# 2021-10-01  AX0432                                        ...
# 2021-10-01  XA0605                                        ...
# 2021-10-01  XC0231                                        ...
# 2021-10-01  D05307                                        ...
# 2021-10-01  XC0022                                        ...
#
#                                           Desc. item Tipo docto.  \
# Fecha
# 2021-10-01  INDV SHAPE GOLD                                  PV
# 2021-10-01   ESPEJO DECORATIVO EDLIN REDONDO GRIS/NG         PV
# 2021-10-01  TAPETE LAZARO GRIS/NEGRO/VER 140X200 435         PV
# 2021-10-01                     SALA MODULAR CESAR 3C         PV
# 2021-10-01   SALA L RECLINO MEAGAN CON BAUL NEGRO 3C         PV
#
#            Nro documento Estado movto.  Bodega  Cant. pedida  \
# Fecha
# 2021-10-01   PV-00000014      Cumplido     100             4
# 2021-10-01   PV-00000229      Cumplido     100             1
# 2021-10-01   PV-00000177      Cumplido       1             1
# 2021-10-01   PV-00000233      Cumplido     100             1
# 2021-10-01   PV-00000234      Cumplido       1             1
#
#             Valor subtotal local  Cliente factura  \
# Fecha
# 2021-10-01                 22521  52692838
# 2021-10-01                607441  1053340687
# 2021-10-01                206900  900703024
# 2021-10-01               2679748  40611356
# 2021-10-01               2834370  79882577
#
#                   Razón social cliente factura Código vendedor  \
# Fecha
# 2021-10-01                    OCAMPO  CAROLINA            F020
# 2021-10-01               PEÑA ROZO DIANA PAOLA            F013
# 2021-10-01                     SHAHARIT S.A.S.            F021
# 2021-10-01                        SUAZA  NORBI            F007
# 2021-10-01  GARIBELLO  MATEUS WILLIAM FERNANDO            F003
#
#                         Nombre vendedor         Desc. tipo inventario  \
# Fecha
# 2021-10-01   SUAREZ SALDAÑA LUISA MARIA           MERCANCIA IMPORTADA
# 2021-10-01   MORENO DIAZ LIDA ESPERANZA           MERCANCIA IMPORTADA
# 2021-10-01  GUERRERO ROZO ERIKA TATIANA           MERCANCIA IMPORTADA
# 2021-10-01        ARIAS HERNANDEZ FREDY  PRODUCTO TERMINADO TAPICERIA
# 2021-10-01          BAQUERO  FREDY RICO           MERCANCIA IMPORTADA
#
#                          ORIGEN                    DEPARTAMENTO  \
# Fecha
# 2021-10-01      IMP - IMPORTADO  P005 - DECORACION Y ACCESORIOS
# 2021-10-01      IMP - IMPORTADO  P005 - DECORACION Y ACCESORIOS
# 2021-10-01      IMP - IMPORTADO  P005 - DECORACION Y ACCESORIOS
# 2021-10-01  MAN - MANUFACTURADO            P003 - SALAS Y SOFAS
# 2021-10-01      IMP - IMPORTADO            P003 - SALAS Y SOFAS
#
#                     CATEGORIA               SUBCATEGORIA
# Fecha
# 2021-10-01    DEM - DECO MESA        INDV - INDIVIDUALES
# 2021-10-01   DEC - DECORACIÓN             ESPE - ESPEJOS
# 2021-10-01      TAP - TAPETES  TAP3 - TAPETES 140X200 CM
# 2021-10-01        SOF - SOFAS     MODU - SOFAS MODULARES
# 2021-10-01  REC - RECLINABLES    RCLL - RECLINABLES EN L

# %% [markdown]
# ## Limpieza de datos
#
# Para este proyecto se selecciona los registro de los pedidos de ventas, en este caso se filtra por la variable **Tipo docto** que sea igual a **PV**, tal como se ilustra a continuación:

# %%
df3 = df2[df2['Tipo docto.'] == 'PV ']

# %% [markdown]
# ## Se renombran las columnas para una mejor legibilidad de los nombres de las varibles
#
# Variable  | Descripción
# -------------------|------------------
# CO             | Código de la tienda
# Desc. C.O.          | Nombre de la tienda
# Desc. item             | Desc_Item
# Desc. C.O.          | Nombre de la tienda
# Tipo docto.             | Tipo_Doc
# Nro documento          | Doc
# Estado movto.             | Estado_Mov
# Cant. pedida          | Cant

# %%
df3 = df3.rename(columns={'C.O.':'CO','Desc. C.O.':'Desc_CO','Desc. item':'Desc_Item','Tipo docto.':'Tipo_Doc','Nro documento':'Doc','Estado movto.':'Estado_Mov',
                         'Cant. pedida':'Cant','Valor subtotal local':'Valor','Cliente factura':'Id','Razón social cliente factura':'Cliente',
                         'Código vendedor':'Cod_Vendedor', 'Nombre vendedor':'Vendedor','Desc. tipo inventario':'Tipo_Inv'})

# %%
df3.columns
# Out:
# Index(['CO', 'Desc_CO', 'Item', 'Referencia', 'Desc_Item', 'Tipo_Doc', 'Doc',
#        'Estado_Mov', 'Bodega', 'Cant', 'Valor', 'Id', 'Cliente',
#        'Cod_Vendedor', 'Vendedor', 'Tipo_Inv', 'ORIGEN', 'DEPARTAMENTO',
#        'CATEGORIA', 'SUBCATEGORIA'],
#       dtype='object')

# %% [markdown]
# ## Limpieza de datos
#
# Dentro del proceso de limpieza de datos se selecciona los registro de las tiendas físicas, toda vez que la compañía cuenta con puntos de ventas online, sin embargo, para el analísis de este proyecto el alcance considera solo las tiendas físicas de la empresa. En este sentido, se toma la variable **CO** y se filtran los códigos **100, 104, 102, 203,101,103,109,105,110**

# %%
df4 = df3[df3.CO.isin([100, 104, 102, 203,101,103,109,105,110])]

# %%
df4.head()
# Out:
#              CO                      Desc_CO  Item  \
# Fecha
# 2021-10-01  100         PUNTO DE VENTA AV 68  1529
# 2021-10-01  100         PUNTO DE VENTA AV 68  4237
# 2021-10-01  100         PUNTO DE VENTA AV 68  1927
# 2021-10-21  104     PUNTO DE VENTA CALLE 134    34
# 2021-10-21  102  PUNTO DE VENTA CENTRO MAYOR   795
#
#                                                    Referencia  \
# Fecha
# 2021-10-01  XA0605                                        ...
# 2021-10-01  D05307                                        ...
# 2021-10-01  XC0022                                        ...
# 2021-10-21  SS0007                                        ...
# 2021-10-21  BR0046                                        ...
#
#                                            Desc_Item Tipo_Doc          Doc  \
# Fecha
# 2021-10-01   ESPEJO DECORATIVO EDLIN REDONDO GRIS/NG      PV   PV-00000229
# 2021-10-01                     SALA MODULAR CESAR 3C      PV   PV-00000233
# 2021-10-01   SALA L RECLINO MEAGAN CON BAUL NEGRO 3C      PV   PV-00000234
# 2021-10-21           SS TRANSPORTE BOGOTA ZONA2 7A10      PV   PV-00000146
# 2021-10-21  ESTANTE PEAK 5 ENT RT3122 RUSTICO/BLANCO      PV   PV-00000184
#
#            Estado_Mov  Bodega  Cant    Valor               Id  \
# Fecha
# 2021-10-01   Cumplido     100     1   607441  1053340687
# 2021-10-01   Cumplido     100     1  2679748  40611356
# 2021-10-01   Cumplido       1     1  2834370  79882577
# 2021-10-21   Cumplido       1     1    60000  51750014
# 2021-10-21   Cumplido       1     1   193912  1000808911
#
#                                        Cliente Cod_Vendedor  \
# Fecha
# 2021-10-01               PEÑA ROZO DIANA PAOLA         F013
# 2021-10-01                        SUAZA  NORBI         F007
# 2021-10-01  GARIBELLO  MATEUS WILLIAM FERNANDO         F003
# 2021-10-21                      VARGAS  SANDRA         F009
# 2021-10-21                        GOMEZ  NICOL         F012
#
#                                   Vendedor                      Tipo_Inv  \
# Fecha
# 2021-10-01      MORENO DIAZ LIDA ESPERANZA           MERCANCIA IMPORTADA
# 2021-10-01           ARIAS HERNANDEZ FREDY  PRODUCTO TERMINADO TAPICERIA
# 2021-10-01             BAQUERO  FREDY RICO           MERCANCIA IMPORTADA
# 2021-10-21  PEÑA VALENZUELA MARIA FERNANDA    VENTA DE TRANSPORTE M/CIAS
# 2021-10-21    FUENTES HERRERA OSCAR JAVIER           MERCANCIA IMPORTADA
#
#                          ORIGEN                    DEPARTAMENTO  \
# Fecha
# 2021-10-01      IMP - IMPORTADO  P005 - DECORACION Y ACCESORIOS
# 2021-10-01  MAN - MANUFACTURADO            P003 - SALAS Y SOFAS
# 2021-10-01      IMP - IMPORTADO            P003 - SALAS Y SOFAS
# 2021-10-21                                     S001 - SERVICIOS
# 2021-10-21      IMP - IMPORTADO                  P006 - ESTUDIO
#
#                     CATEGORIA             SUBCATEGORIA
# Fecha
# 2021-10-01   DEC - DECORACIÓN           ESPE - ESPEJOS
# 2021-10-01        SOF - SOFAS   MODU - SOFAS MODULARES
# 2021-10-01  REC - RECLINABLES  RCLL - RECLINABLES EN L
# 2021-10-21        S00 - OTROS        TRAN - TRANSPORTE
# 2021-10-21     EST - ESTANTES          ESTA - ESTANTES

# %% [markdown]
# ## Limpieza de datos
#
# Así mismo, se seleccionan los registros de los pedidos en donde la variable **Estado_Mov** tengas las siguientes categorías: **Cumplido, Aprobado, Comprometido**

# %%
df5 = df4[df4.Estado_Mov.isin(['Cumplido','Aprobado', 'Comprometido'])]

# %%
df5.head()
# Out:
#              CO                      Desc_CO  Item  \
# Fecha
# 2021-10-01  100         PUNTO DE VENTA AV 68  1529
# 2021-10-01  100         PUNTO DE VENTA AV 68  4237
# 2021-10-01  100         PUNTO DE VENTA AV 68  1927
# 2021-10-21  104     PUNTO DE VENTA CALLE 134    34
# 2021-10-21  102  PUNTO DE VENTA CENTRO MAYOR   795
#
#                                                    Referencia  \
# Fecha
# 2021-10-01  XA0605                                        ...
# 2021-10-01  D05307                                        ...
# 2021-10-01  XC0022                                        ...
# 2021-10-21  SS0007                                        ...
# 2021-10-21  BR0046                                        ...
#
#                                            Desc_Item Tipo_Doc          Doc  \
# Fecha
# 2021-10-01   ESPEJO DECORATIVO EDLIN REDONDO GRIS/NG      PV   PV-00000229
# 2021-10-01                     SALA MODULAR CESAR 3C      PV   PV-00000233
# 2021-10-01   SALA L RECLINO MEAGAN CON BAUL NEGRO 3C      PV   PV-00000234
# 2021-10-21           SS TRANSPORTE BOGOTA ZONA2 7A10      PV   PV-00000146
# 2021-10-21  ESTANTE PEAK 5 ENT RT3122 RUSTICO/BLANCO      PV   PV-00000184
#
#            Estado_Mov  Bodega  Cant    Valor               Id  \
# Fecha
# 2021-10-01   Cumplido     100     1   607441  1053340687
# 2021-10-01   Cumplido     100     1  2679748  40611356
# 2021-10-01   Cumplido       1     1  2834370  79882577
# 2021-10-21   Cumplido       1     1    60000  51750014
# 2021-10-21   Cumplido       1     1   193912  1000808911
#
#                                        Cliente Cod_Vendedor  \
# Fecha
# 2021-10-01               PEÑA ROZO DIANA PAOLA         F013
# 2021-10-01                        SUAZA  NORBI         F007
# 2021-10-01  GARIBELLO  MATEUS WILLIAM FERNANDO         F003
# 2021-10-21                      VARGAS  SANDRA         F009
# 2021-10-21                        GOMEZ  NICOL         F012
#
#                                   Vendedor                      Tipo_Inv  \
# Fecha
# 2021-10-01      MORENO DIAZ LIDA ESPERANZA           MERCANCIA IMPORTADA
# 2021-10-01           ARIAS HERNANDEZ FREDY  PRODUCTO TERMINADO TAPICERIA
# 2021-10-01             BAQUERO  FREDY RICO           MERCANCIA IMPORTADA
# 2021-10-21  PEÑA VALENZUELA MARIA FERNANDA    VENTA DE TRANSPORTE M/CIAS
# 2021-10-21    FUENTES HERRERA OSCAR JAVIER           MERCANCIA IMPORTADA
#
#                          ORIGEN                    DEPARTAMENTO  \
# Fecha
# 2021-10-01      IMP - IMPORTADO  P005 - DECORACION Y ACCESORIOS
# 2021-10-01  MAN - MANUFACTURADO            P003 - SALAS Y SOFAS
# 2021-10-01      IMP - IMPORTADO            P003 - SALAS Y SOFAS
# 2021-10-21                                     S001 - SERVICIOS
# 2021-10-21      IMP - IMPORTADO                  P006 - ESTUDIO
#
#                     CATEGORIA             SUBCATEGORIA
# Fecha
# 2021-10-01   DEC - DECORACIÓN           ESPE - ESPEJOS
# 2021-10-01        SOF - SOFAS   MODU - SOFAS MODULARES
# 2021-10-01  REC - RECLINABLES  RCLL - RECLINABLES EN L
# 2021-10-21        S00 - OTROS        TRAN - TRANSPORTE
# 2021-10-21     EST - ESTANTES          ESTA - ESTANTES

# %% [markdown]
# ## Limpieza de los datos
#
# Finalmente dentro de este ejercicio de la limpieza de los datos se verifica que no exista ningún campo en ***Null***, así mismo, se eliminan los espacios de los datos de la variable **Referencia** miente la función **Strip()** como se detalla a continuación:

# %%
verificarNull = df5.isnull().values.any()
TotalNull=df5.isnull().sum().sum()

print(verificarNull,TotalNull)
# Out:
# False 0

# %%
df5.Referencia = df5.Referencia.str.strip()

# %%
df5
# Out:
#              CO                       Desc_CO  Item Referencia  \
# Fecha
# 2021-10-01  100          PUNTO DE VENTA AV 68  1529     XA0605
# 2021-10-01  100          PUNTO DE VENTA AV 68  4237     D05307
# 2021-10-01  100          PUNTO DE VENTA AV 68  1927     XC0022
# 2021-10-21  104      PUNTO DE VENTA CALLE 134    34     SS0007
# 2021-10-21  102   PUNTO DE VENTA CENTRO MAYOR   795     BR0046
# ...         ...                           ...   ...        ...
# 2022-01-06  104      PUNTO DE VENTA CALLE 134  1773     XA0740
# 2022-01-06  102   PUNTO DE VENTA CENTRO MAYOR  2012     XC0072
# 2022-01-07  101         PUNTO DE VENTA OUTLET  4158     C00438
# 2022-01-08  100          PUNTO DE VENTA AV 68  2096     XC0120
# 2022-01-10  105  PUNTO DE VENTA PLAZA CENTRAL  6980     SS0155
#
#                                            Desc_Item Tipo_Doc          Doc  \
# Fecha
# 2021-10-01   ESPEJO DECORATIVO EDLIN REDONDO GRIS/NG      PV   PV-00000229
# 2021-10-01                     SALA MODULAR CESAR 3C      PV   PV-00000233
# 2021-10-01   SALA L RECLINO MEAGAN CON BAUL NEGRO 3C      PV   PV-00000234
# 2021-10-21           SS TRANSPORTE BOGOTA ZONA2 7A10      PV   PV-00000146
# 2021-10-21  ESTANTE PEAK 5 ENT RT3122 RUSTICO/BLANCO      PV   PV-00000184
# ...                                              ...      ...          ...
# 2022-01-06               SILLA AUXILIAR DELICIA AZUL      PV   PV-00000423
# 2022-01-06                  PUFF DOBLE WITHBUTH GRIS      PV   PV-00000548
# 2022-01-07                         COJIN DINI GRANDE      PV   PV-00000453
# 2022-01-08         COMEDOR ESTHER CAOBA 4P WENGUE 4C      PV   PV-00001129
# 2022-01-10           SERVICIO CAMBIO COLOR PATAS C/U      PV   PV-00000301
#
#            Estado_Mov  Bodega  Cant    Valor               Id  \
# Fecha
# 2021-10-01   Cumplido     100     1   607441  1053340687
# 2021-10-01   Cumplido     100     1  2679748  40611356
# 2021-10-01   Cumplido       1     1  2834370  79882577
# 2021-10-21   Cumplido       1     1    60000  51750014
# 2021-10-21   Cumplido       1     1   193912  1000808911
# ...               ...     ...   ...      ...              ...
# 2022-01-06   Cumplido     104     1   371344  63523637
# 2022-01-06   Cumplido       1     1   223445  52449765
# 2022-01-07   Cumplido     101     2    33177  52786228
# 2022-01-08   Cumplido       1     1  1329328  1024496659
# 2022-01-10   Cumplido       1     4    40000  52777322
#
#                                        Cliente Cod_Vendedor  \
# Fecha
# 2021-10-01               PEÑA ROZO DIANA PAOLA         F013
# 2021-10-01                        SUAZA  NORBI         F007
# 2021-10-01  GARIBELLO  MATEUS WILLIAM FERNANDO         F003
# 2021-10-21                      VARGAS  SANDRA         F009
# 2021-10-21                        GOMEZ  NICOL         F012
# ...                                        ...          ...
# 2022-01-06                      DUARTE  ANDREA         F001
# 2022-01-06             BARRERA  MARIA ANGELICA         F032
# 2022-01-07       MONTEALEGRE QUINTERO BRIGITTE         F008
# 2022-01-08        SALCEDO TRIANA MARTHA MAGLYS         F030
# 2022-01-10                      CARDONA  LUISA         F012
#
#                                   Vendedor                      Tipo_Inv  \
# Fecha
# 2021-10-01      MORENO DIAZ LIDA ESPERANZA           MERCANCIA IMPORTADA
# 2021-10-01           ARIAS HERNANDEZ FREDY  PRODUCTO TERMINADO TAPICERIA
# 2021-10-01             BAQUERO  FREDY RICO           MERCANCIA IMPORTADA
# 2021-10-21  PEÑA VALENZUELA MARIA FERNANDA    VENTA DE TRANSPORTE M/CIAS
# 2021-10-21    FUENTES HERRERA OSCAR JAVIER           MERCANCIA IMPORTADA
# ...                                    ...                           ...
# 2022-01-06                 SANABRIA  NIDIA           MERCANCIA IMPORTADA
# 2022-01-06             RESTREPO  JHONNATAN           MERCANCIA IMPORTADA
# 2022-01-07          CASTILLO SIERRA ANDRES  PRODUCTO TERMINADO TAPICERIA
# 2022-01-08                GRANADOS  CARLOS           MERCANCIA IMPORTADA
# 2022-01-10    FUENTES HERRERA OSCAR JAVIER   VENTA SERV ARREGLOS MUEBLES
#
#                          ORIGEN                    DEPARTAMENTO  \
# Fecha
# 2021-10-01      IMP - IMPORTADO  P005 - DECORACION Y ACCESORIOS
# 2021-10-01  MAN - MANUFACTURADO            P003 - SALAS Y SOFAS
# 2021-10-01      IMP - IMPORTADO            P003 - SALAS Y SOFAS
# 2021-10-21                                     S001 - SERVICIOS
# 2021-10-21      IMP - IMPORTADO                  P006 - ESTUDIO
# ...                         ...                             ...
# 2022-01-06      IMP - IMPORTADO            P003 - SALAS Y SOFAS
# 2022-01-06      IMP - IMPORTADO            P003 - SALAS Y SOFAS
# 2022-01-07       NAC - NACIONAL  P005 - DECORACION Y ACCESORIOS
# 2022-01-08      IMP - IMPORTADO                P001 - COMEDORES
# 2022-01-10                                     S001 - SERVICIOS
#
#                        CATEGORIA             SUBCATEGORIA
# Fecha
# 2021-10-01      DEC - DECORACIÓN           ESPE - ESPEJOS
# 2021-10-01           SOF - SOFAS   MODU - SOFAS MODULARES
# 2021-10-01     REC - RECLINABLES  RCLL - RECLINABLES EN L
# 2021-10-21           S00 - OTROS        TRAN - TRANSPORTE
# 2021-10-21        EST - ESTANTES          ESTA - ESTANTES
# ...                          ...                      ...
# 2022-01-06       POL - POLTRONAS         POLT - POLTRONAS
# 2022-01-06            PUF - PUFF              PUFF - PUFF
# 2022-01-07      DEC - DECORACIÓN           COJN - COJINES
# 2022-01-08  SCO - SET DE COMEDOR            SET4 - SET 4P
# 2022-01-10           S00 - OTROS             OTRO - OTROS
#
# [13767 rows x 20 columns]

# %% [markdown]
# ## Transformación de la variable ***Valor***
#
# Para una mayor practicidad en el manejo de los datos, se transformó la variable **Valor** en millones de pesos en la variable **ValorMM**.

# %%
df5['ValorMM']=df5['Valor']/1000000

# %%
df5['Vlr_UnitarioMM']=df5['ValorMM']/df5['Cant']

# %% [markdown]
# ## Analisis Preliminar
#
# A través de la funciones **describe()** y **dtypes**, se analiza la estructura de los datos y sus valores.

# %%
df5.describe()
# Out:
#                  CO          Item        Bodega          Cant         Valor  \
# count  13767.000000  13767.000000  13767.000000  13767.000000  1.376700e+04
# mean     111.642333   2383.145493     78.980606      1.195613  4.609198e+05
# std       28.989000   2124.962476    158.698958      0.979976  5.675907e+05
# min      100.000000     18.000000      1.000000      1.000000  0.000000e+00
# 25%      100.000000    431.000000      1.000000      1.000000  6.000000e+04
# 50%      102.000000   1796.000000      1.000000      1.000000  2.187610e+05
# 75%      104.000000   4203.000000    101.000000      1.000000  7.562190e+05
# max      203.000000   7303.000000    923.000000     80.000000  5.466731e+06
#
#             ValorMM  Vlr_UnitarioMM
# count  13767.000000    13767.000000
# mean       0.460920        0.433863
# std        0.567591        0.544461
# min        0.000000        0.000000
# 25%        0.060000        0.060000
# 50%        0.218761        0.199538
# 75%        0.756219        0.683051
# max        5.466731        3.424286

# %%
df5.dtypes
# Out:
# CO                  int64
# Desc_CO            object
# Item                int64
# Referencia         object
# Desc_Item          object
# Tipo_Doc           object
# Doc                object
# Estado_Mov         object
# Bodega              int64
# Cant                int64
# Valor               int64
# Id                 object
# Cliente            object
# Cod_Vendedor       object
# Vendedor           object
# Tipo_Inv           object
# ORIGEN             object
# DEPARTAMENTO       object
# CATEGORIA          object
# SUBCATEGORIA       object
# ValorMM           float64
# Vlr_UnitarioMM    float64
# dtype: object

# %%
df5 = df5.astype({'CO': 'object', 'Item': 'object','Bodega': 'object'})

# %%
df5.dtypes
# Out:
# CO                 object
# Desc_CO            object
# Item               object
# Referencia         object
# Desc_Item          object
# Tipo_Doc           object
# Doc                object
# Estado_Mov         object
# Bodega             object
# Cant                int64
# Valor               int64
# Id                 object
# Cliente            object
# Cod_Vendedor       object
# Vendedor           object
# Tipo_Inv           object
# ORIGEN             object
# DEPARTAMENTO       object
# CATEGORIA          object
# SUBCATEGORIA       object
# ValorMM           float64
# Vlr_UnitarioMM    float64
# dtype: object

# %%
df5.head()
# Out:
#              CO                      Desc_CO  Item Referencia  \
# Fecha
# 2021-10-01  100         PUNTO DE VENTA AV 68  1529     XA0605
# 2021-10-01  100         PUNTO DE VENTA AV 68  4237     D05307
# 2021-10-01  100         PUNTO DE VENTA AV 68  1927     XC0022
# 2021-10-21  104     PUNTO DE VENTA CALLE 134    34     SS0007
# 2021-10-21  102  PUNTO DE VENTA CENTRO MAYOR   795     BR0046
#
#                                            Desc_Item Tipo_Doc          Doc  \
# Fecha
# 2021-10-01   ESPEJO DECORATIVO EDLIN REDONDO GRIS/NG      PV   PV-00000229
# 2021-10-01                     SALA MODULAR CESAR 3C      PV   PV-00000233
# 2021-10-01   SALA L RECLINO MEAGAN CON BAUL NEGRO 3C      PV   PV-00000234
# 2021-10-21           SS TRANSPORTE BOGOTA ZONA2 7A10      PV   PV-00000146
# 2021-10-21  ESTANTE PEAK 5 ENT RT3122 RUSTICO/BLANCO      PV   PV-00000184
#
#            Estado_Mov Bodega  Cant  ...                             Cliente  \
# Fecha                               ...
# 2021-10-01   Cumplido    100     1  ...               PEÑA ROZO DIANA PAOLA
# 2021-10-01   Cumplido    100     1  ...                        SUAZA  NORBI
# 2021-10-01   Cumplido      1     1  ...  GARIBELLO  MATEUS WILLIAM FERNANDO
# 2021-10-21   Cumplido      1     1  ...                      VARGAS  SANDRA
# 2021-10-21   Cumplido      1     1  ...                        GOMEZ  NICOL
#
#            Cod_Vendedor                        Vendedor  \
# Fecha
# 2021-10-01         F013      MORENO DIAZ LIDA ESPERANZA
# 2021-10-01         F007           ARIAS HERNANDEZ FREDY
# 2021-10-01         F003             BAQUERO  FREDY RICO
# 2021-10-21         F009  PEÑA VALENZUELA MARIA FERNANDA
# 2021-10-21         F012    FUENTES HERRERA OSCAR JAVIER
#
#                                 Tipo_Inv               ORIGEN  \
# Fecha
# 2021-10-01           MERCANCIA IMPORTADA      IMP - IMPORTADO
# 2021-10-01  PRODUCTO TERMINADO TAPICERIA  MAN - MANUFACTURADO
# 2021-10-01           MERCANCIA IMPORTADA      IMP - IMPORTADO
# 2021-10-21    VENTA DE TRANSPORTE M/CIAS
# 2021-10-21           MERCANCIA IMPORTADA      IMP - IMPORTADO
#
#                               DEPARTAMENTO          CATEGORIA  \
# Fecha
# 2021-10-01  P005 - DECORACION Y ACCESORIOS   DEC - DECORACIÓN
# 2021-10-01            P003 - SALAS Y SOFAS        SOF - SOFAS
# 2021-10-01            P003 - SALAS Y SOFAS  REC - RECLINABLES
# 2021-10-21                S001 - SERVICIOS        S00 - OTROS
# 2021-10-21                  P006 - ESTUDIO     EST - ESTANTES
#
#                        SUBCATEGORIA   ValorMM Vlr_UnitarioMM
# Fecha
# 2021-10-01           ESPE - ESPEJOS  0.607441       0.607441
# 2021-10-01   MODU - SOFAS MODULARES  2.679748       2.679748
# 2021-10-01  RCLL - RECLINABLES EN L  2.834370       2.834370
# 2021-10-21        TRAN - TRANSPORTE  0.060000       0.060000
# 2021-10-21          ESTA - ESTANTES  0.193912       0.193912
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Agrupaciones
#
# Una vez realizado el proceso de limpieza y estructuración de los datos, se procede a realizar las agrupaciones de los mismos por diferentes varialbles de interés como se describe a continuación:

# %%
AgrupacionTienda=df5.groupby('Desc_CO')

# %%
AgrupacionTienda.get_group("PUNTO DE VENTA AV 68")
# Out:
#              CO               Desc_CO  Item Referencia  \
# Fecha
# 2021-10-01  100  PUNTO DE VENTA AV 68  1529     XA0605
# 2021-10-01  100  PUNTO DE VENTA AV 68  4237     D05307
# 2021-10-01  100  PUNTO DE VENTA AV 68  1927     XC0022
# 2021-10-21  100  PUNTO DE VENTA AV 68  6714     XC0274
# 2021-10-21  100  PUNTO DE VENTA AV 68   623     AX0318
# ...         ...                   ...   ...        ...
# 2021-12-03  100  PUNTO DE VENTA AV 68  1373     XA0518
# 2021-12-05  100  PUNTO DE VENTA AV 68  4969     BR0082
# 2021-12-05  100  PUNTO DE VENTA AV 68   479     AX0155
# 2021-12-12  100  PUNTO DE VENTA AV 68   578     AX0270
# 2022-01-08  100  PUNTO DE VENTA AV 68  2096     XC0120
#
#                                            Desc_Item Tipo_Doc          Doc  \
# Fecha
# 2021-10-01   ESPEJO DECORATIVO EDLIN REDONDO GRIS/NG      PV   PV-00000229
# 2021-10-01                     SALA MODULAR CESAR 3C      PV   PV-00000233
# 2021-10-01   SALA L RECLINO MEAGAN CON BAUL NEGRO 3C      PV   PV-00000234
# 2021-10-21   COMEDOR EUDALIA 6P CAOBA SILLAS GRIS 5C      PV   PV-00000407
# 2021-10-21  ADORNO ERIZO ROSA                             PV   PV-00000407
# ...                                              ...      ...          ...
# 2021-12-03               COMEDOR WAGNER 6P  3C NEGRO      PV   PV-00000812
# 2021-12-05          MESA DE NOCHE FRANCIA BLANCO 814      PV   PV-00000856
# 2021-12-05  FLORERO VIDRIO AZUL BAJO                      PV   PV-00000856
# 2021-12-12   CUADRO CANVAS CON MARCO ABSTRAC 80*80CM      PV   PV-00000920
# 2022-01-08         COMEDOR ESTHER CAOBA 4P WENGUE 4C      PV   PV-00001129
#
#            Estado_Mov Bodega  Cant  ...                             Cliente  \
# Fecha                               ...
# 2021-10-01   Cumplido    100     1  ...               PEÑA ROZO DIANA PAOLA
# 2021-10-01   Cumplido    100     1  ...                        SUAZA  NORBI
# 2021-10-01   Cumplido      1     1  ...  GARIBELLO  MATEUS WILLIAM FERNANDO
# 2021-10-21   Cumplido      1     1  ...            RONDON ESCOBAR KATHERINE
# 2021-10-21   Cumplido    100     1  ...            RONDON ESCOBAR KATHERINE
# ...               ...    ...   ...  ...                                 ...
# 2021-12-03   Cumplido      1     1  ...    RAMIREZ MANJARRES NICOLL NATALIA
# 2021-12-05   Cumplido    100     1  ...                   QUINTERO  CLAUDIA
# 2021-12-05   Cumplido    100     1  ...                   QUINTERO  CLAUDIA
# 2021-12-12   Cumplido    100     2  ...               LOPEZ RUBIANA YOLANDA
# 2022-01-08   Cumplido      1     1  ...        SALCEDO TRIANA MARTHA MAGLYS
#
#            Cod_Vendedor                         Vendedor  \
# Fecha
# 2021-10-01         F013       MORENO DIAZ LIDA ESPERANZA
# 2021-10-01         F007            ARIAS HERNANDEZ FREDY
# 2021-10-01         F003              BAQUERO  FREDY RICO
# 2021-10-21         F023  NIETO GUERRERO LOURDES ANDREINA
# 2021-10-21         F023  NIETO GUERRERO LOURDES ANDREINA
# ...                 ...                              ...
# 2021-12-03         F007            ARIAS HERNANDEZ FREDY
# 2021-12-05         F007            ARIAS HERNANDEZ FREDY
# 2021-12-05         F007            ARIAS HERNANDEZ FREDY
# 2021-12-12         F024            IBAÑEZ BOHORQEZ EDWIN
# 2022-01-08         F030                 GRANADOS  CARLOS
#
#                                 Tipo_Inv               ORIGEN  \
# Fecha
# 2021-10-01           MERCANCIA IMPORTADA      IMP - IMPORTADO
# 2021-10-01  PRODUCTO TERMINADO TAPICERIA  MAN - MANUFACTURADO
# 2021-10-01           MERCANCIA IMPORTADA      IMP - IMPORTADO
# 2021-10-21           MERCANCIA IMPORTADA      IMP - IMPORTADO
# 2021-10-21           MERCANCIA IMPORTADA      IMP - IMPORTADO
# ...                                  ...                  ...
# 2021-12-03           MERCANCIA IMPORTADA      IMP - IMPORTADO
# 2021-12-05           MERCANCIA IMPORTADA      IMP - IMPORTADO
# 2021-12-05           MERCANCIA IMPORTADA      IMP - IMPORTADO
# 2021-12-12           MERCANCIA IMPORTADA      IMP - IMPORTADO
# 2022-01-08           MERCANCIA IMPORTADA      IMP - IMPORTADO
#
#                               DEPARTAMENTO             CATEGORIA  \
# Fecha
# 2021-10-01  P005 - DECORACION Y ACCESORIOS      DEC - DECORACIÓN
# 2021-10-01            P003 - SALAS Y SOFAS           SOF - SOFAS
# 2021-10-01            P003 - SALAS Y SOFAS     REC - RECLINABLES
# 2021-10-21                P001 - COMEDORES  SCO - SET DE COMEDOR
# 2021-10-21  P005 - DECORACION Y ACCESORIOS      DEC - DECORACIÓN
# ...                                    ...                   ...
# 2021-12-03                P001 - COMEDORES  SCO - SET DE COMEDOR
# 2021-12-05                  P002 - ALCOBAS  MNO - MESAS DE NOCHE
# 2021-12-05  P005 - DECORACION Y ACCESORIOS      DEC - DECORACIÓN
# 2021-12-12  P005 - DECORACION Y ACCESORIOS      DEC - DECORACIÓN
# 2022-01-08                P001 - COMEDORES  SCO - SET DE COMEDOR
#
#                        SUBCATEGORIA   ValorMM Vlr_UnitarioMM
# Fecha
# 2021-10-01           ESPE - ESPEJOS  0.607441       0.607441
# 2021-10-01   MODU - SOFAS MODULARES  2.679748       2.679748
# 2021-10-01  RCLL - RECLINABLES EN L  2.834370       2.834370
# 2021-10-21            SET6 - SET 6P  1.745046       1.745046
# 2021-10-21           ADOR - ADORNOS  0.030168       0.030168
# ...                             ...       ...            ...
# 2021-12-03            SET6 - SET 6P  0.853698       0.853698
# 2021-12-05    MNOC - MESAS DE NOCHE  0.212521       0.212521
# 2021-12-05          FLOR - FLOREROS  0.026807       0.026807
# 2021-12-12           CUAD - CUADROS  0.327563       0.163781
# 2022-01-08            SET4 - SET 4P  1.329328       1.329328
#
# [3836 rows x 22 columns]

# %% [markdown]
# ## Agrupaciones
#
# Con la siguiente agrupación se buscar determinar el desempeño por cada uno de los asesores en ventas en cada uno de los departamentos o líneas de producción.

# %%
Asesor_Dpto= df5.groupby(['Cod_Vendedor','DEPARTAMENTO'])
Asesor_Dpto.sum()
# Out:
#                                              Cant     Valor    ValorMM  \
# Cod_Vendedor DEPARTAMENTO
# F000         P001 - COMEDORES                  37  12352291  12.352291
#              P002 - ALCOBAS                     3    291502   0.291502
#              P003 - SALAS Y SOFAS              30  26677967  26.677967
#              P005 - DECORACION Y ACCESORIOS    95   3696022   3.696022
#              P006 - ESTUDIO                     1    210840   0.210840
# ...                                           ...       ...        ...
# F040         P002 - ALCOBAS                     6   2577647   2.577647
#              P003 - SALAS Y SOFAS              18  11099522  11.099522
#              P005 - DECORACION Y ACCESORIOS    31   1780804   1.780804
#              P006 - ESTUDIO                     4    721511   0.721511
#              S001 - SERVICIOS                  17   1090000   1.090000
#
#                                              Vlr_UnitarioMM
# Cod_Vendedor DEPARTAMENTO
# F000         P001 - COMEDORES                     10.622602
#              P002 - ALCOBAS                        0.291502
#              P003 - SALAS Y SOFAS                 25.617940
#              P005 - DECORACION Y ACCESORIOS        3.333400
#              P006 - ESTUDIO                        0.210840
# ...                                                     ...
# F040         P002 - ALCOBAS                        2.577647
#              P003 - SALAS Y SOFAS                 11.099522
#              P005 - DECORACION Y ACCESORIOS        1.706854
#              P006 - ESTUDIO                        0.721511
#              S001 - SERVICIOS                      1.090000
#
# [174 rows x 4 columns]

# %% [markdown]
# ## Operaciones con las agrupaciones
#
# Utilizando las funciones de agregación **Sum** de Groupby, se totoliza las variables cuantitativas de los ventas realiazadas por cada una de las tiendas físicas seleccionadas en los apartados anteriores.

# %%
Vlr_Pedidos_Tienda=df5.groupby('Desc_CO').sum()
Vlr_Pedidos_Tienda
# Out:
#                                Cant       Valor      ValorMM  Vlr_UnitarioMM
# Desc_CO
# PUNTO DE VENTA AV 68           4484  1863683909  1863.683909     1743.429993
# PUNTO DE VENTA CALI            1598   638843822   638.843822      600.082573
# PUNTO DE VENTA CALLE 134       2163   907878232   907.878232      853.969499
# PUNTO DE VENTA CC SANTA FE      197    59973253    59.973253       58.220784
# PUNTO DE VENTA CENTRO MAYOR    2401  1066379557  1066.379557     1009.938773
# PUNTO DE VENTA OUTLET          1976   429536456   429.536456      403.359905
# PUNTO DE VENTA PLAZA CENTRAL   1352   480664118   480.664118      453.515063
# PUNTO DE VENTA PLAZA IMPERIAL  1304   538919130   538.919130      511.803570
# PUNTO DE VENTA VILLA DEL RIO    985   359605002   359.605002      338.672797

# %% [markdown]
# ## Operaciones con las agrupaciones
#
# Utilizando las funciones de agregación **Sum** de Groupby, se totoliza las variables cuantitativas de las ventas realiazadas según las categorías del catálogo de productos que tiene Muebles Fiotti.

# %%
Vlr_Pedidos_Categoria=df5.groupby('CATEGORIA').sum()
Vlr_Pedidos_Categoria
# Out:
#                                   Cant       Valor      ValorMM  \
# CATEGORIA
#                                     21    22170809    22.170809
# ARM - ARMARIO                       21     8491001     8.491001
# BCA - BASE CAMAS                   178    58767345    58.767345
# BIB - BIBLIOTECAS                  104    23208810    23.208810
# BIF - BIFFET                        92    37254226    37.254226
# BOT - BOTANICA                     360     6241483     6.241483
# CAB - CABECEROS                    107    41253851    41.253851
# CAM - CAMAS                         47    31074681    31.074681
# CEE - CENTROS DE ENTRETENIMIENTO   181    74643866    74.643866
# CMT - CAMAROTES                     23    23646334    23.646334
# COL - COLCHONES                    148   120619377   120.619377
# COM - COMODAS                       20     9222161     9.222161
# CON - CONSOLAS                      42    15703002    15.703002
# DEC - DECORACIÓN                  2885    96284081    96.284081
# DEM - DECO MESA                    665    12710430    12.710430
# ESC - ESCRITORIOS                  170    52555655    52.555655
# EST - ESTANTES                     117    26636394    26.636394
# FIG - FIGURAS                       38      456595     0.456595
# ILU - ILUMINACIÓN                   55     5622773     5.622773
# LEN - LENCERÍA                      54     3218111     3.218111
# MCO - MESAS DE COMEDOR             252   152037309   152.037309
# MES - MESAS                        688   166072613   166.072613
# MNO - MESAS DE NOCHE               154    30911417    30.911417
# PER - PERCHEROS                     13     1434904     1.434904
# POL - POLTRONAS                    619   301187489   301.187489
# PRO - PROPS                          9      498777     0.498777
# PUF - PUFF                         224    31537404    31.537404
# REC - RECLINABLES                  709  1173123914  1173.123914
# S00 - OTROS                       2662   137984781   137.984781
# SCO - SET DE COMEDOR              1089   975476566   975.476566
# SFC - SOFA CAMA                    750   742748313   742.748313
# SIL - SILLAS                      1634   260389979   260.389979
# SIO - SILLAS DE OFICINA             81    20735123    20.735123
# SOF - SOFAS                       1492  1563590413  1563.590413
# TAP - TAPETES                      756   117973492   117.973492
#
#                                   Vlr_UnitarioMM
# CATEGORIA
#                                        22.170809
# ARM - ARMARIO                           7.200562
# BCA - BASE CAMAS                       57.202219
# BIB - BIBLIOTECAS                      20.660474
# BIF - BIFFET                           36.692125
# BOT - BOTANICA                          5.150782
# CAB - CABECEROS                        40.585451
# CAM - CAMAS                            30.337114
# CEE - CENTROS DE ENTRETENIMIENTO       73.917143
# CMT - CAMAROTES                        21.034737
# COL - COLCHONES                       111.380886
# COM - COMODAS                           9.222161
# CON - CONSOLAS                         15.703002
# DEC - DECORACIÓN                       81.309545
# DEM - DECO MESA                         9.778970
# ESC - ESCRITORIOS                      52.374932
# EST - ESTANTES                         25.753801
# FIG - FIGURAS                           0.448095
# ILU - ILUMINACIÓN                       5.173050
# LEN - LENCERÍA                          2.425155
# MCO - MESAS DE COMEDOR                151.092939
# MES - MESAS                           164.346611
# MNO - MESAS DE NOCHE                   21.739862
# PER - PERCHEROS                         0.958686
# POL - POLTRONAS                       242.314545
# PRO - PROPS                             0.327907
# PUF - PUFF                             29.439143
# REC - RECLINABLES                    1131.273194
# S00 - OTROS                           133.954260
# SCO - SET DE COMEDOR                  974.205848
# SFC - SOFA CAMA                       736.311418
# SIL - SILLAS                           97.333866
# SIO - SILLAS DE OFICINA                20.316576
# SOF - SOFAS                          1524.227383
# TAP - TAPETES                         116.629706

# %% [markdown]
# ## Operaciones con las agrupaciones
#
# Utilizando las funciones de agregación **Sum** de Groupby, se totoliza las variables cuantitativas de las ventas realiazadas según las subcategorías del catálogo de productos que tiene Muebles Fiotti.

# %%
Vlr_Pedidos_Subcategoria=df5.groupby('SUBCATEGORIA').sum()
Vlr_Pedidos_Subcategoria

# %% [markdown]
# ## Análisis de la variable **Cant**
#
# En las siguientes líneas de código se pretente analizar el comportamiento de la variable **Cant** que corresponde a  la cantidad de pedidos realizados en cada una de las tiendas físicas que tiene Muebles Fiotti

# %%
Cant_Tienda2=AgrupacionTienda['Cant']

# %%
Cant_Tienda2=AgrupacionTienda['Cant'].sum()
Cant_Tienda2
# Out:
# Desc_CO
# PUNTO DE VENTA AV 68             4484
# PUNTO DE VENTA CALI              1598
# PUNTO DE VENTA CALLE 134         2163
# PUNTO DE VENTA CC SANTA FE        197
# PUNTO DE VENTA CENTRO MAYOR      2401
# PUNTO DE VENTA OUTLET            1976
# PUNTO DE VENTA PLAZA CENTRAL     1352
# PUNTO DE VENTA PLAZA IMPERIAL    1304
# PUNTO DE VENTA VILLA DEL RIO      985
# Name: Cant, dtype: int64

# %%
Cant_Tienda2.describe()
# Out:
#                                 count      mean       std  min  25%  50%  75%  \
# Desc_CO
# PUNTO DE VENTA AV 68           3836.0  1.168926  0.698020  1.0  1.0  1.0  1.0
# PUNTO DE VENTA CALI            1251.0  1.277378  0.884873  1.0  1.0  1.0  1.0
# PUNTO DE VENTA CALLE 134       1872.0  1.155449  0.592923  1.0  1.0  1.0  1.0
# PUNTO DE VENTA CC SANTA FE      165.0  1.193939  0.854664  1.0  1.0  1.0  1.0
# PUNTO DE VENTA CENTRO MAYOR    2112.0  1.136837  0.604520  1.0  1.0  1.0  1.0
# PUNTO DE VENTA OUTLET          1418.0  1.393512  2.297312  1.0  1.0  1.0  1.0
# PUNTO DE VENTA PLAZA CENTRAL   1179.0  1.146735  0.564675  1.0  1.0  1.0  1.0
# PUNTO DE VENTA PLAZA IMPERIAL  1109.0  1.175834  0.710108  1.0  1.0  1.0  1.0
# PUNTO DE VENTA VILLA DEL RIO    825.0  1.193939  0.633768  1.0  1.0  1.0  1.0
#
#                                 max
# Desc_CO
# PUNTO DE VENTA AV 68           12.0
# PUNTO DE VENTA CALI            10.0
# PUNTO DE VENTA CALLE 134       11.0
# PUNTO DE VENTA CC SANTA FE      8.0
# PUNTO DE VENTA CENTRO MAYOR     8.0
# PUNTO DE VENTA OUTLET          80.0
# PUNTO DE VENTA PLAZA CENTRAL    6.0
# PUNTO DE VENTA PLAZA IMPERIAL   8.0
# PUNTO DE VENTA VILLA DEL RIO    6.0

# %%
Asesor_Dpto.size()
# Out:
# Cod_Vendedor  DEPARTAMENTO
# F000          P001 - COMEDORES                  23
#               P002 - ALCOBAS                     3
#               P003 - SALAS Y SOFAS              28
#               P005 - DECORACION Y ACCESORIOS    67
#               P006 - ESTUDIO                     1
#                                                 ..
# F040          P002 - ALCOBAS                     6
#               P003 - SALAS Y SOFAS              18
#               P005 - DECORACION Y ACCESORIOS    25
#               P006 - ESTUDIO                     4
#               S001 - SERVICIOS                  17
# Length: 174, dtype: int64

# %% [markdown]
# ## Agrupaciones con funciones de agregación
#
# En las siguientes líneas de codígo se realiza un agregado por tienda física y departamento o línea de productos, utilizando funciones de agregación de Numpy como **Sum** y **Mean**

# %%
df5.groupby(['Desc_CO','DEPARTAMENTO']).aggregate(
    {
        'ValorMM':np.sum,
        'Cant':np.sum,
        'Vlr_UnitarioMM':np.mean
        
    }

)
# Out:
#                                                                 ValorMM  Cant  \
# Desc_CO                      DEPARTAMENTO
# FERIAS COMERCIALES           P001 - COMEDORES                  2.370878    10
#                              P003 - SALAS Y SOFAS             25.406914    33
#                              P005 - DECORACION Y ACCESORIOS    0.948235     9
#                              P006 - ESTUDIO                    0.748287     4
#                              S001 - SERVICIOS                  0.730000    10
# ...                                                                 ...   ...
# PUNTO DE VENTA VILLA DEL RIO P003 - SALAS Y SOFAS            235.041992   228
#                              P005 - DECORACION Y ACCESORIOS   21.113908   391
#                              P006 - ESTUDIO                    8.456976    32
#                              S001 - SERVICIOS                  7.806000   158
#                              S002 - OTROS                      0.001840     1
#
#                                                              Vlr_UnitarioMM
# Desc_CO                      DEPARTAMENTO
# FERIAS COMERCIALES           P001 - COMEDORES                      0.306950
#                              P003 - SALAS Y SOFAS                  0.769906
#                              P005 - DECORACION Y ACCESORIOS        0.147157
#                              P006 - ESTUDIO                        0.187072
#                              S001 - SERVICIOS                      0.073000
# ...                                                                     ...
# PUNTO DE VENTA VILLA DEL RIO P003 - SALAS Y SOFAS                  1.051572
#                              P005 - DECORACION Y ACCESORIOS        0.065554
#                              P006 - ESTUDIO                        0.264281
#                              S001 - SERVICIOS                      0.052027
#                              S002 - OTROS                          0.001840
#
# [63 rows x 3 columns]

# %% [markdown]
# ## Gráficas
#
# ### Histogramas

# %%
df5["DEPARTAMENTO"].hist();

# %% [markdown]
# ## Gráficas
#
# ### Scatter Plot

# %%
df5.plot.scatter(x='ValorMM',y='DEPARTAMENTO');

# %%
df5.plot.scatter(x='Vlr_UnitarioMM',y='DEPARTAMENTO');

# %% [markdown]
# ## Consolidación de las ventas por semanas
#
# Se consolida la información por semnas desde el 1 de octubre de 2021 hasta el 31 de marzo de 2022

# %%
dfSemana=df5.resample('W').sum()

# %%
dfSemana
# Out:
#             Cant      Valor     ValorMM  Vlr_UnitarioMM
# Fecha
# 2021-10-03   345  116036717  116.036717      105.639975
# 2021-10-10   596  252640516  252.640516      236.426571
# 2021-10-17   604  206738046  206.738046      192.449349
# 2021-10-24   737  258088850  258.088850      237.619934
# 2021-10-31   649  226497807  226.497807      209.177107
# 2021-11-07   602  277627591  277.627591      262.693206
# 2021-11-14   616  259558853  259.558853      243.659611
# 2021-11-21   764  343455821  343.455821      334.090536
# 2021-11-28   678  312677662  312.677662      294.239306
# 2021-12-05   837  324488103  324.488103      314.424595
# 2021-12-12   807  268417345  268.417345      254.687668
# 2021-12-19   762  276206115  276.206115      258.110826
# 2021-12-26   455  179561954  179.561954      171.138767
# 2022-01-02   368  126128133  126.128133      119.199270
# 2022-01-09   483  195211635  195.211635      181.273368
# 2022-01-16   665  212359728  212.359728      197.148344
# 2022-01-23   761  259793144  259.793144      249.317467
# 2022-01-30   694  251762818  251.762818      234.857239
# 2022-02-06   756  277287322  277.287322      257.486133
# 2022-02-13   692  260131044  260.131044      242.241667
# 2022-02-20   578  242123438  242.123438      227.347999
# 2022-02-27   522  208361684  208.361684      200.183024
# 2022-03-06   433  175706753  175.706753      160.031274
# 2022-03-13   618  247095736  247.095736      234.253031
# 2022-03-20   576  221010121  221.010121      206.669625
# 2022-03-27   589  263022425  263.022425      251.982014
# 2022-04-03   273  103494118  103.494118       96.645051

# %% [markdown]
# ## Gráfico
#
# Mediante la función **Plot** se analiza el comportamiento de las ventas en cada una de las semanas

# %%
dfSemana['ValorMM'].plot(figsize = (20,5), color = "red")
plt.title("Ventas", size = 24)
plt.show()

# %% [markdown]
# ## Consolidación de las ventas por semanas
#
# Se consolida la información por **días** desde el 1 de octubre de 2021 hasta el 31 de marzo de 2022

# %%
dfDia=df5.resample('D').sum()

# %%
dfDia
# Out:
#             Cant     Valor    ValorMM  Vlr_UnitarioMM         wn
# Fecha
# 2021-10-01    66  31382591  31.382591       29.351831  29.239797
# 2021-10-02   124  38540605  38.540605       36.788161  51.807059
# 2021-10-03   155  46113521  46.113521       39.499984  48.973628
# 2021-10-04    57  21304623  21.304623       20.252475  20.420193
# 2021-10-05    68  32584416  32.584416       31.185879  27.727675
# ...          ...       ...        ...             ...        ...
# 2022-03-27    96  54116218  54.116218       52.517479  35.537795
# 2022-03-28    74  30259922  30.259922       27.942972  29.601729
# 2022-03-29    61  31955495  31.955495       29.350033  25.339065
# 2022-03-30    75  25614979  25.614979       24.936239  25.898523
# 2022-03-31    63  15663722  15.663722       14.415806  26.920022
#
# [182 rows x 5 columns]

# %% [markdown]
# ## Gráfico
#
# Mediante la función **Plot** se analiza el comportamiento de las ventas por cada uno de los días, entre el 1 de octubre de 2021 hasta el 31 de marzo de 2022

# %%
dfDia['ValorMM'].plot(figsize = (20,5), color = "red")
plt.title("Ventas", size = 24)
plt.show()

# %% [markdown]
# ## Prueba de normalidad
#
# Tomando la base consolidada por días se busca realizar la prueba de normalidad para observar la relación de la recta con los diferentes puntos cercanos a ella a través de la gráfica de QQ Plot.

# %%
scipy.stats.probplot(dfDia.ValorMM, plot =  plt)
plt.title("QQ Plot", size = 24)
plt.show()

# %% [markdown]
# ## Prueba de normalidad
#
# Tomando la base consolidada por semanas se busca realizar la prueba de normalidad para observar la relación de la recta con los diferentes puntos cercanos a ella a través de la gráfica de QQ Plot.

# %%
scipy.stats.probplot(dfSemana.ValorMM, plot =  plt)
plt.title("QQ Plot", size = 24)
plt.show()

# %% [markdown]
# ## Análisis del ruido blanco

# %%
#White Noise
wn = np.random.normal(loc = df5.ValorMM.mean(), scale = df5.ValorMM.std(), size = len(df5))
df5['wn'] = wn

# %%
df5.head()
# Out:
#              CO                      Desc_CO  Item Referencia  \
# Fecha
# 2021-10-01  100         PUNTO DE VENTA AV 68  1529     XA0605
# 2021-10-01  100         PUNTO DE VENTA AV 68  4237     D05307
# 2021-10-01  100         PUNTO DE VENTA AV 68  1927     XC0022
# 2021-10-21  104     PUNTO DE VENTA CALLE 134    34     SS0007
# 2021-10-21  102  PUNTO DE VENTA CENTRO MAYOR   795     BR0046
#
#                                            Desc_Item Tipo_Doc          Doc  \
# Fecha
# 2021-10-01   ESPEJO DECORATIVO EDLIN REDONDO GRIS/NG      PV   PV-00000229
# 2021-10-01                     SALA MODULAR CESAR 3C      PV   PV-00000233
# 2021-10-01   SALA L RECLINO MEAGAN CON BAUL NEGRO 3C      PV   PV-00000234
# 2021-10-21           SS TRANSPORTE BOGOTA ZONA2 7A10      PV   PV-00000146
# 2021-10-21  ESTANTE PEAK 5 ENT RT3122 RUSTICO/BLANCO      PV   PV-00000184
#
#            Estado_Mov Bodega  Cant  ...  Cod_Vendedor  \
# Fecha                               ...
# 2021-10-01   Cumplido    100     1  ...          F013
# 2021-10-01   Cumplido    100     1  ...          F007
# 2021-10-01   Cumplido      1     1  ...          F003
# 2021-10-21   Cumplido      1     1  ...          F009
# 2021-10-21   Cumplido      1     1  ...          F012
#
#                                   Vendedor                      Tipo_Inv  \
# Fecha
# 2021-10-01      MORENO DIAZ LIDA ESPERANZA           MERCANCIA IMPORTADA
# 2021-10-01           ARIAS HERNANDEZ FREDY  PRODUCTO TERMINADO TAPICERIA
# 2021-10-01             BAQUERO  FREDY RICO           MERCANCIA IMPORTADA
# 2021-10-21  PEÑA VALENZUELA MARIA FERNANDA    VENTA DE TRANSPORTE M/CIAS
# 2021-10-21    FUENTES HERRERA OSCAR JAVIER           MERCANCIA IMPORTADA
#
#                          ORIGEN                    DEPARTAMENTO  \
# Fecha
# 2021-10-01      IMP - IMPORTADO  P005 - DECORACION Y ACCESORIOS
# 2021-10-01  MAN - MANUFACTURADO            P003 - SALAS Y SOFAS
# 2021-10-01      IMP - IMPORTADO            P003 - SALAS Y SOFAS
# 2021-10-21                                     S001 - SERVICIOS
# 2021-10-21      IMP - IMPORTADO                  P006 - ESTUDIO
#
#                     CATEGORIA             SUBCATEGORIA   ValorMM  \
# Fecha
# 2021-10-01   DEC - DECORACIÓN           ESPE - ESPEJOS  0.607441
# 2021-10-01        SOF - SOFAS   MODU - SOFAS MODULARES  2.679748
# 2021-10-01  REC - RECLINABLES  RCLL - RECLINABLES EN L  2.834370
# 2021-10-21        S00 - OTROS        TRAN - TRANSPORTE  0.060000
# 2021-10-21     EST - ESTANTES          ESTA - ESTANTES  0.193912
#
#            Vlr_UnitarioMM        wn
# Fecha
# 2021-10-01       0.607441  0.094746
# 2021-10-01       2.679748 -0.172450
# 2021-10-01       2.834370  0.990715
# 2021-10-21       0.060000  1.115054
# 2021-10-21       0.193912  1.079467
#
# [5 rows x 23 columns]

# %%
df5.wn.plot(figsize = (20,5))
plt.title("White Noise Time-Series", size= 24)
plt.show()

# %%
dfSemana.ValorMM.plot(figsize=(20,5))
plt.title("AAAAA", size = 24)
plt.ylim(0,400)
plt.show()

# %% [markdown]
# ## Análisis de regresión

# %%
import matplotlib.dates as mdates

# %%
#sns.regplot(x=dfDia.index.values,y=dfDia["ValorMM"])
sns.regplot(x=mdates.date2num(dfDia.index),y=dfDia["ValorMM"])
# Out:
# <AxesSubplot:ylabel='ValorMM'>

# %%
sns.regplot(x=mdates.date2num(dfSemana.index),y=dfSemana["ValorMM"])
#sns.regplot(x=mdates.date2num(df.index), y=df['target'])
# Out:
# <AxesSubplot:ylabel='ValorMM'>

# %% [markdown]
# ## Análisis de correlación

# %%
from pandas.plotting import autocorrelation_plot

# %%
autocorrelation_plot(dfDia["ValorMM"])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
autocorrelation_plot(dfSemana["ValorMM"])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
s_dec_additive = seasonal_decompose(dfDia["ValorMM"], model = "additive")
s_dec_additive.plot()
plt.show()

# %%
s_dec_multiplicative = seasonal_decompose(dfDia["ValorMM"], model = "multiplicative")
s_dec_multiplicative.plot()
plt.show()
