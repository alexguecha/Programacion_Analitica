# %%
#Matrices
import numpy as np

#Matemáticas
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats

import statsmodels.graphics.tsaplots as sgt 
import statsmodels.tsa.stattools as sts 
from statsmodels.tsa.seasonal import seasonal_decompose
import seaborn as sns
sns.set()

#libreria excel
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
df_pedidos = pd.read_excel('./PEDIDOS_POR_ITEM.xls', sheet_name='Sheet1')

# %%
df_pedidos
# Out:
#        C.O.            Desc. C.O.      Fecha  Item  \
# 0       903     PAGINA WEB FIOTTI 2021-10-01   705
# 1       100  PUNTO DE VENTA AV 68 2021-10-01  1529
# 2       902      VENTAS DIGITALES 2021-10-01  1890
# 3       100  PUNTO DE VENTA AV 68 2021-10-01  4237
# 4       100  PUNTO DE VENTA AV 68 2021-10-01  1927
# ...     ...                   ...        ...   ...
# 17336   203   PUNTO DE VENTA CALI 2022-01-11  4222
# 17337   203   PUNTO DE VENTA CALI 2022-01-11  4210
# 17338   203   PUNTO DE VENTA CALI 2022-01-11  4214
# 17339     1        ADMINISTRACIÓN 2022-01-11  6942
# 17340     1        ADMINISTRACIÓN 2022-01-11  4214
#
#                                               Referencia  \
# 0      AX0432                                        ...
# 1      XA0605                                        ...
# 2      XC0231                                        ...
# 3      D05307                                        ...
# 4      XC0022                                        ...
# ...                                                  ...
# 17336  D00986                                        ...
# 17337  D00904                                        ...
# 17338  D00935                                        ...
# 17339  D00504                                        ...
# 17340  D00935                                        ...
#
#                                      Desc. item        Detalle ext. 1  \
# 0      INDV SHAPE GOLD                                            NaN
# 1       ESPEJO DECORATIVO EDLIN REDONDO GRIS/NG                   NaN
# 2      TAPETE LAZARO GRIS/NEGRO/VER 140X200 435                   NaN
# 3                         SALA MODULAR CESAR 3C  00031
# 4       SALA L RECLINO MEAGAN CON BAUL NEGRO 3C                   NaN
# ...                                         ...                   ...
# 17336                            SOFA LANCER 2P  00188
# 17337                            POLTRONA VACIA  00035
# 17338                          SOFA CAMA SITTON  00083
# 17339                            SOFA CELAYA 2P  00188
# 17340                          SOFA CAMA SITTON  00020
#
#       Desc. detalle ext. 1 Tipo docto. Nro documento  ...          CATEGORIA  \
# 0                      NaN         PV    PV-00000014  ...    DEM - DECO MESA
# 1                      NaN         PV    PV-00000229  ...   DEC - DECORACIÓN
# 2                      NaN         PV    PV-00000177  ...      TAP - TAPETES
# 3                F-168 AGO         PV    PV-00000233  ...        SOF - SOFAS
# 4                      NaN         PV    PV-00000234  ...  REC - RECLINABLES
# ...                    ...         ...           ...  ...                ...
# 17336            A-310 AGO         PTR  PTR-00000010  ...        SOF - SOFAS
# 17337            F-172 N3          PTR  PTR-00000010  ...    POL - POLTRONAS
# 17338            F-932 AGO         PTR  PTR-00000010  ...    SFC - SOFA CAMA
# 17339            A-310 AGO         PTR  PTR-00000063  ...        SOF - SOFAS
# 17340            F-140 AGO         PTR  PTR-00000063  ...    SFC - SOFA CAMA
#
#                     SUBCATEGORIA Divisor márgen promedio  \
# 0            INDV - INDIVIDUALES                   22521
# 1                 ESPE - ESPEJOS                  607441
# 2      TAP3 - TAPETES 140X200 CM                  206900
# 3         MODU - SOFAS MODULARES                 2679748
# 4        RCLL - RECLINABLES EN L                 2834370
# ...                          ...                     ...
# 17336             SOF2 - SOFA 2P                       0
# 17337           POLT - POLTRONAS                       0
# 17338  SFCA - SOFA CAMA ABATIBLE                       0
# 17339             SOF2 - SOFA 2P                       0
# 17340  SFCA - SOFA CAMA ABATIBLE                       0
#
#        Divisor márgen estándar  f_rowid_movto numero f_rowid_pv_docto f_rowid  \
# 0                        22521         589338     14           365336  365336
# 1                       607441         589349    229           365342  365342
# 2                       206900         589372    177           365356  365356
# 3                      2679748         589389    233           365362  365362
# 4                      2834370         589390    234           365363  365363
# ...                        ...            ...    ...              ...     ...
# 17336                        0         615539     10           375436  375436
# 17337                        0         615542     10           375436  375436
# 17338                        0         615559     10           375436  375436
# 17339                        0         615599     63           375450  375450
# 17340                        0         615602     63           375450  375450
#
#       f_utilidad_promedio_f id_clase_docto
# 0                  14113.00            502
# 1                 401917.60            503
# 2                 116257.00            502
# 3                1148205.00            503
# 4                1726947.00            503
# ...                     ...            ...
# 17336            -499827.00            506
# 17337            -300484.67            506
# 17338            -354123.00            506
# 17339            -500129.00            506
# 17340            -348614.00            506
#
# [17341 rows x 35 columns]

# %%
df_pedidos.describe()
# Out:
#                C.O.          Item        Bodega  Cant. pedida  \
# count  17341.000000  17341.000000  17341.000000  17341.000000
# mean     172.921458   2611.926994     71.235454      1.344328
# std      222.778435   2169.667157    149.541124      4.142133
# min        1.000000     18.000000      1.000000      1.000000
# 25%      100.000000    563.000000      1.000000      1.000000
# 50%      103.000000   1988.000000     40.000000      1.000000
# 75%      105.000000   4214.000000    101.000000      1.000000
# max      903.000000   7326.000000    923.000000    200.000000
#
#        Valor subtotal local  Divisor márgen promedio  Divisor márgen estándar  \
# count          1.734100e+04             1.734100e+04             1.734100e+04
# mean           4.235740e+05             4.235740e+05             4.235740e+05
# std            5.543910e+05             5.543910e+05             5.543910e+05
# min            0.000000e+00             0.000000e+00             0.000000e+00
# 25%            4.671400e+04             4.671400e+04             4.671400e+04
# 50%            1.755460e+05             1.755460e+05             1.755460e+05
# 75%            6.503360e+05             6.503360e+05             6.503360e+05
# max            6.175800e+06             6.175800e+06             6.175800e+06
#
#        f_rowid_movto        numero  f_rowid_pv_docto        f_rowid  \
# count   17341.000000  17341.000000      17341.000000   17341.000000
# mean   611367.102416    506.561732     373966.586414  373966.586414
# std     12307.299838    404.192646       4663.447355    4663.447355
# min    589336.000000      1.000000     365334.000000  365334.000000
# 25%    601146.000000    198.000000     370230.000000  370230.000000
# 50%    611105.000000    410.000000     373697.000000  373697.000000
# 75%    621757.000000    698.000000     377868.000000  377868.000000
# max    632654.000000   1725.000000     382089.000000  382089.000000
#
#        f_utilidad_promedio_f  id_clase_docto
# count           1.734100e+04    17341.000000
# mean            9.114183e+04      503.132807
# std             5.286735e+05        0.902360
# min            -7.248160e+06      502.000000
# 25%             9.321370e+03      503.000000
# 50%             6.468900e+04      503.000000
# 75%             2.210393e+05      503.000000
# max             3.110823e+06      506.000000

# %%
df_pedidos.columns
# Out:
# Index(['C.O.', 'Desc. C.O.', 'Fecha', 'Item', 'Referencia', 'Desc. item',
#        'Detalle ext. 1', 'Desc. detalle ext. 1', 'Tipo docto.',
#        'Nro documento', 'Estado movto.', 'Bodega', 'U.M.', 'Cant. pedida',
#        'Valor subtotal local', 'Cliente factura',
#        'Razón social cliente factura', 'Código vendedor', 'Nombre vendedor',
#        'Condición de pago', 'Desc. condición de pago', 'Desc. cond. pago fact',
#        'Desc. tipo inventario', 'ORIGEN', 'DEPARTAMENTO', 'CATEGORIA',
#        'SUBCATEGORIA', 'Divisor márgen promedio', 'Divisor márgen estándar',
#        'f_rowid_movto', 'numero', 'f_rowid_pv_docto', 'f_rowid',
#        'f_utilidad_promedio_f', 'id_clase_docto'],
#       dtype='object')

# %%
df_pedidos["CATEGORIA"]=df_pedidos["CATEGORIA"].astype("category")
df_pedidos["CATEGORIA"]
# Out:
# 0          DEM - DECO MESA
# 1         DEC - DECORACIÓN
# 2            TAP - TAPETES
# 3              SOF - SOFAS
# 4        REC - RECLINABLES
#                ...
# 17336          SOF - SOFAS
# 17337      POL - POLTRONAS
# 17338      SFC - SOFA CAMA
# 17339          SOF - SOFAS
# 17340      SFC - SOFA CAMA
# Name: CATEGORIA, Length: 17341, dtype: category
# Categories (35, object): [' ', 'ARM - ARMARIO', 'BCA - BASE CAMAS', 'BIB - BIBLIOTECAS', ..., 'SIL - SILLAS', 'SIO - SILLAS DE OFICINA', 'SOF - SOFAS', 'TAP - TAPETES']

# %%
df_pedidos["CATEGORIA"].hist();

# %%
df_pedidos.hist(column='Cant. pedida', by='CATEGORIA')
